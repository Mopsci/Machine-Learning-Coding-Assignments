# %% [markdown]
# # Assignment: Linear Classification
# <font color = 'red'>Complete the TODO sections below...</font><br>
# <b> Name: <br>
# <b> Email:

# %% [markdown]
# # Loading Data

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
# Download dataset from: https://www.kaggle.com/mig555/mushroom-classification
dataset = pd.read_csv('mushrooms.csv')

# %%
#Thus we have 22 features(1st one is label) and 8124 instances.
print(dataset.shape)
dataset.head()
# Out:
# (8124, 23)
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color   ...   stalk-surface-below-ring  \
# 0            c         n          k   ...                          s
# 1            c         b          k   ...                          s
# 2            c         b          n   ...                          s
# 3            c         n          n   ...                          s
# 4            w         b          k   ...                          s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# 1                      w                      w         p          w
# 2                      w                      w         p          w
# 3                      w                      w         p          w
# 4                      w                      w         p          w
#
#   ring-number ring-type spore-print-color population habitat
# 0           o         p                 k          s       u
# 1           o         p                 n          n       g
# 2           o         p                 n          n       m
# 3           o         p                 k          s       u
# 4           o         e                 n          a       g
#
# [5 rows x 23 columns]

# %%
dataset.describe()
# Out:
#        class cap-shape cap-surface cap-color bruises  odor gill-attachment  \
# count   8124      8124        8124      8124    8124  8124            8124
# unique     2         6           4        10       2     9               2
# top        e         x           y         n       f     n               f
# freq    4208      3656        3244      2284    4748  3528            7914
#
#        gill-spacing gill-size gill-color   ...   stalk-surface-below-ring  \
# count          8124      8124       8124   ...                       8124
# unique            2         2         12   ...                          4
# top               c         b          b   ...                          s
# freq           6812      5612       1728   ...                       4936
#
#        stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# count                    8124                   8124      8124       8124
# unique                      9                      9         1          4
# top                         w                      w         p          w
# freq                     4464                   4384      8124       7924
#
#        ring-number ring-type spore-print-color population habitat
# count         8124      8124              8124       8124    8124
# unique           3         5                 9          6       7
# top              o         p                 w          v       d
# freq          7488      3968              2388       4040    3148
#
# [4 rows x 23 columns]

# %% [markdown]
# # Pre-processing

# %% [markdown]
# <font color = 'red'>TODO: Remove Null values of any </font>

# %%
# Let's check if there are any Null values in the datset. 
# YOUR CODE...
# Out:
# class                       0
# cap-shape                   0
# cap-surface                 0
# cap-color                   0
# bruises                     0
# odor                        0
# gill-attachment             0
# gill-spacing                0
# gill-size                   0
# gill-color                  0
# stalk-shape                 0
# stalk-root                  0
# stalk-surface-above-ring    0
# stalk-surface-below-ring    0
# stalk-color-above-ring      0
# stalk-color-below-ring      0
# veil-type                   0
# veil-color                  0
# ring-number                 0
# ring-type                   0
# spore-print-color           0
# population                  0
# habitat                     0
# dtype: int64

# %% [markdown]
# We can see that the dataset has values in strings.We need to convert all the unique values to integers. Thus we perform label encoding on the data. <font color ='red'>TODO: Use sklearn to perform label encoding on the dataset. You may use the following link for reference: <br>https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.LabelEncoder.html </font>

# %%
#Your dataset might look similar to mine...
# YOUR CODE...
# Out:
#    class  cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0      1          5            2          4        1     6                1
# 1      0          5            2          9        1     0                1
# 2      0          0            2          8        1     3                1
# 3      1          5            3          8        1     6                1
# 4      0          5            2          3        0     5                1
#
#    gill-spacing  gill-size  gill-color   ...     stalk-surface-below-ring  \
# 0             0          1           4   ...                            2
# 1             0          0           4   ...                            2
# 2             0          0           5   ...                            2
# 3             0          1           5   ...                            2
# 4             1          0           4   ...                            2
#
#    stalk-color-above-ring  stalk-color-below-ring  veil-type  veil-color  \
# 0                       7                       7          0           2
# 1                       7                       7          0           2
# 2                       7                       7          0           2
# 3                       7                       7          0           2
# 4                       7                       7          0           2
#
#    ring-number  ring-type  spore-print-color  population  habitat
# 0            1          4                  2           3        5
# 1            1          4                  3           2        1
# 2            1          4                  3           2        3
# 3            1          4                  2           3        5
# 4            1          0                  3           0        1
#
# [5 rows x 23 columns]

# %%
# There are two classes Poisonous and edible (1: p, 0: e). There are 4208 p's and 3916 e's.
print(dataset.groupby('class').size())
# Out:
# class
# 0    4208
# 1    3916
# dtype: int64

# %% [markdown]
# <font color = 'red'>TODO: Convert our dataframe (dataset) to matrices X and T </font>

# %%
#YOUR CODE...

# %% [markdown]
# <font color = 'red'>TODO: Normalize/Standardize the X matrix (Scale the data to be between -1 and 1). You may use Sklearn for this purpose. Refer to this link: <br> https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.StandardScaler.html

# %% [markdown]
# <font color = 'red'>TODO: Further add 'ones' as bias to X</font>

# %%
X
# Out:
# array([[ 1.        ,  1.02971224,  0.14012794, ..., -0.67019486,
#         -0.5143892 ,  2.03002809],
#        [ 1.        ,  1.02971224,  0.14012794, ..., -0.2504706 ,
#         -1.31310821, -0.29572966],
#        [ 1.        , -2.08704716,  0.14012794, ..., -0.2504706 ,
#         -1.31310821,  0.86714922],
#        ...,
#        [ 1.        , -0.8403434 ,  0.14012794, ..., -1.50964337,
#         -2.11182722,  0.28570978],
#        [ 1.        , -0.21699152,  0.95327039, ...,  1.42842641,
#          0.28432981,  0.28570978],
#        [ 1.        ,  1.02971224,  0.14012794, ...,  0.16925365,
#         -2.11182722,  0.28570978]])

# %%
X.shape
# Out:
# (8124, 23)

# %%
#You do not have to normalize the T matrix.
T
# Out:
# 0       1
# 1       0
# 2       0
# 3       1
# 4       0
# 5       0
# 6       0
# 7       0
# 8       1
# 9       0
# 10      0
# 11      0
# 12      0
# 13      1
# 14      0
# 15      0
# 16      0
# 17      1
# 18      1
# 19      1
# 20      0
# 21      1
# 22      0
# 23      0
# 24      0
# 25      1
# 26      0
# 27      0
# 28      0
# 29      0
#        ..
# 8094    0
# 8095    1
# 8096    0
# 8097    1
# 8098    1
# 8099    0
# 8100    0
# 8101    1
# 8102    0
# 8103    0
# 8104    0
# 8105    0
# 8106    0
# 8107    0
# 8108    1
# 8109    0
# 8110    0
# 8111    0
# 8112    0
# 8113    1
# 8114    1
# 8115    0
# 8116    1
# 8117    1
# 8118    1
# 8119    0
# 8120    0
# 8121    0
# 8122    1
# 8123    0
# Name: class, Length: 8124, dtype: int64

# %% [markdown]
# <font color = 'red'>TODO: Use sklearn.model_selection's train_test_split to split our data into training and testing.</font>

# %%
from sklearn.model_selection import train_test_split
#YOUR CODE...

# %% [markdown]
# # Logistic Regression

# %% [markdown]
# <font color = 'red'>TODO: Use sklearn to implement Logisitic Regression on X_train and y_train</font>

# %%
#YOUR CODE...
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
# Metrices for accuracy. Go through these in sklearn's documentation...
from sklearn.model_selection import cross_val_predict, cross_val_score
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score

# %%
# I have completed the function below which will print all the accuracy measures...
def print_score(classifier,X_train,y_train,X_test,y_test,train=True):
    if train == True:
        print("Training results:\n")
        print('Accuracy Score: {0:.4f}\n'.format(accuracy_score(y_train,classifier.predict(X_train))))
        print('Classification Report:\n{}\n'.format(classification_report(y_train,classifier.predict(X_train))))
        print('Confusion Matrix:\n{}\n'.format(confusion_matrix(y_train,classifier.predict(X_train))))
        res = cross_val_score(classifier, X_train, y_train, cv=10, n_jobs=-1, scoring='accuracy')
        print('Average Accuracy:\t{0:.4f}\n'.format(res.mean()))
        print('Standard Deviation:\t{0:.4f}'.format(res.std()))
    elif train == False:
        print("Test results:\n")
        print('Accuracy Score: {0:.4f}\n'.format(accuracy_score(y_test,classifier.predict(X_test))))
        print('Classification Report:\n{}\n'.format(classification_report(y_test,classifier.predict(X_test))))
        print('Confusion Matrix:\n{}\n'.format(confusion_matrix(y_test,classifier.predict(X_test))))

# %%
#Here's how my model performed...
print_score(classifier,X_train,y_train,X_test,y_test,train=True)
# Out:
# Training results:
#
# Accuracy Score: 0.9518
#
# Classification Report:
#              precision    recall  f1-score   support
#
#           0       0.95      0.96      0.95      2951
#           1       0.95      0.94      0.95      2735
#
# avg / total       0.95      0.95      0.95      5686
#
#
# Confusion Matrix:
# [[2829  122]
#  [ 152 2583]]
#
# Average Accuracy:	0.9508
#
# Standard Deviation:	0.0090
