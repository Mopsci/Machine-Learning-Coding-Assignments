# %%
print("Brandon Huegerich - ITCS3134-001")
# Out:
# Brandon Huegerich - ITCS3134-001

# %%
i = 0
while i<=5:
    print(i*2)
    i = i + 1
# Out:
# 0
# 2
# 4
# 6
# 8
# 10

# %%
print("Enter first number: ")
x = input()
x = int(x)
print("Enter second number: ")
y = input()
y = int(y)
print("first plus second number is:", x+y)
# Out:
# Enter first number:
# 2
# Enter second number:
# 4
# first plus second number is: 6

# %%
arr = ["T","E","S","T"]
start = 0
end = len(arr) - 1
while True:
    temp = arr[start]
    arr[start] = arr[end]
    arr[end] = temp
    start = start + 1
    end = end - 1
    if(start >= end):
        for i in arr:
            print(i)
        break
# Out:
# T
# S
# E
# T

# %%
x = "Assignment"
print(i)
print(x[0:2] + x[i-2:i])
# Out:
# 10
# Asnt

# %%
for x in range(1000,3001):
    if(x%5==0):
        if(x%7!=0):
            print(x)
# Out:
# 1000
# 1005
# 1010
# 1020
# 1025
# 1030
# 1035
# 1040
# 1045
# 1055
# 1060
# 1065
# 1070
# 1075
# 1080
# 1090
# 1095
# 1100
# 1105
# 1110
# 1115
# 1125
# 1130
# 1135
# 1140
# 1145
# 1150
# 1160
# 1165
# 1170
# 1175
# 1180
# 1185
# 1195
# 1200
# 1205
# 1210
# 1215
# 1220
# 1230
# 1235
# 1240
# 1245
# 1250
# 1255
# 1265
# 1270
# 1275
# 1280
# 1285
# 1290
# 1300
# 1305
# 1310
# 1315
# 1320
# 1325
# 1335
# 1340
# 1345
# 1350
# 1355
# 1360
# 1370
# 1375
# 1380
# 1385
# 1390
# 1395
# 1405
# 1410
# 1415
# 1420
# 1425
# 1430
# 1440
# 1445
# 1450
# 1455
# 1460
# 1465
# 1475
# 1480
# 1485
# 1490
# 1495
# 1500
# 1510
# 1515
# 1520
# 1525
# 1530
# 1535
# 1545
# 1550
# 1555
# 1560
# 1565
# 1570
# 1580
# 1585
# 1590
# 1595
# 1600
# 1605
# 1615
# 1620
# 1625
# 1630
# 1635
# 1640
# 1650
# 1655
# 1660
# 1665
# 1670
# 1675
# 1685
# 1690
# 1695
# 1700
# 1705
# 1710
# 1720
# 1725
# 1730
# 1735
# 1740
# 1745
# 1755
# 1760
# 1765
# 1770
# 1775
# 1780
# 1790
# 1795
# 1800
# 1805
# 1810
# 1815
# 1825
# ...

# %%
import sys
print(sys.getsizeof("this"))
print(sys.getsizeof("this is a test"))
arr = ["this", "is", "a","test"]
print(sys.getsizeof(arr))
# Out:
# 53
# 63
# 96

# %%
#Getting the coefficient of the equation
print("For the equation ar^2+br+c")
print("Enter a: ")
a = input()
a = int(a)
print("Enter b:")
b = input()
b = int(b)
print("Enter b:")
c = input()
c = int(c)

d = b**2-4*a*c
root1 = ((-b + d**(1/2))/2*a)
root2 = ((-b - d**(1/2))/2*a)

print(root1, root2)
# Out:
# For the equation ar^2+br+c
# Enter a:
# 1
# Enter b:
# 6
# Enter b:
# 9
# -3.0 -3.0

# %%
for i in range (1,6):
    print(i*"*")
# Out:
# *
# **
# ***
# ****
# *****

# %%
# This function adds two numbers 
def add(x, y):
   return x + y

# This function subtracts two numbers 
def subtract(x, y):
   return x - y

# This function multiplies two numbers
def multiply(x, y):
   return x * y

# This function divides two numbers
def divide(x, y):
   return x / y

print("Select operation.")
print("1.Add")
print("2.Subtract")
print("3.Multiply")
print("4.Divide")

# Take input from the user 
choice = input("Enter choice(1/2/3/4):")

num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))

if choice == '1':
   print(num1,"+",num2,"=", add(num1,num2))

elif choice == '2':
   print(num1,"-",num2,"=", subtract(num1,num2))

elif choice == '3':
   print(num1,"*",num2,"=", multiply(num1,num2))

elif choice == '4':
   print(num1,"/",num2,"=", divide(num1,num2))
else:
   print("Invalid input")
# Out:
# Select operation.
# 1.Add
# 2.Subtract
# 3.Multiply
# 4.Divide
# Enter choice(1/2/3/4):1
# Enter first number: 3
# Enter second number: 4
# 3 + 4 = 7
